# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
state_master_df = pd.read_csv("../data/state-master-data.csv")

# %%
state_master_df.head(10)
# Out:
#    Unnamed: 0                 state Abb        date  population   Latitude  \
# 0           0               Alabama  AL  2021-02-22     4903185  32.601011
# 1           1                Alaska  AK  2021-02-22      731545  61.302501
# 2           2               Arizona  AZ  2021-02-22     7278717  34.168219
# 3           3              Arkansas  AR  2021-02-22     3017804  34.751928
# 4           4            California  CA  2021-02-22    39512223  37.271875
# 5           5              Colorado  CO  2021-02-22     5758736  38.997934
# 6           6           Connecticut  CT  2021-02-22     3565287  41.518784
# 7           7              Delaware  DE  2021-02-22      973764  39.145251
# 8           8  District of Columbia  DC  2021-02-22      705749  38.899349
# 9           9               Florida  FL  2021-02-22    21477737  27.975728
#
#     Longitude    cases  deaths  total_distributed  total_administered  \
# 0  -86.680736   487520    9592            1082100              788613
# 1 -158.775020    57316     279             299935              235141
# 2 -111.930907   809899   15502            1688255             1469676
# 3  -92.131378   315759    5363             691525              528467
# 4 -119.270415  3536446   49531            9178020             7453468
# 5 -105.550567   424097    5990            1348800             1202161
# 6  -72.757507   275334    7562             984275              860534
# 7  -75.418921    85090    1368             204200              180940
# 8  -77.014567    39755     995             225125              162674
# 9  -83.833017  1872915   30064            5120975             4387051
#
#    percent_vaccinated  est_percent_infected_to_date  est_percent_immune
# 0               16.08                          9.96               26.08
# 1               32.14                          7.84               39.99
# 2               20.19                         11.15               31.39
# 3               17.51                         10.48               28.02
# 4               18.86                          8.96               27.85
# 5               20.88                          7.37               28.27
# 6               24.14                          7.74               31.93
# 7               18.58                          8.75               27.36
# 8               23.05                          5.64               28.72
# 9               20.43                          8.73               29.19

# %%
state_master_df.drop(columns={"Unnamed: 0"}, inplace=True)

# %%
state_master_df.corr()
# Out:
#                               population  Latitude  Longitude     cases  \
# population                      1.000000 -0.281456   0.040734  0.988946
# Latitude                       -0.281456  1.000000  -0.050076 -0.298470
# Longitude                       0.040734 -0.050076   1.000000  0.015236
# cases                           0.988946 -0.298470   0.015236  1.000000
# deaths                          0.941370 -0.261971   0.129639  0.936877
# total_distributed               0.995571 -0.272832   0.034749  0.983684
# total_administered              0.994787 -0.270845   0.037552  0.981556
# percent_vaccinated             -0.332108  0.417061  -0.387152 -0.334255
# est_percent_infected_to_date    0.025753  0.026220  -0.038763  0.130018
# est_percent_immune             -0.257631  0.360593  -0.343043 -0.193422
#
#                                 deaths  total_distributed  total_administered  \
# population                    0.941370           0.995571            0.994787
# Latitude                     -0.261971          -0.272832           -0.270845
# Longitude                     0.129639           0.034749            0.037552
# cases                         0.936877           0.983684            0.981556
# deaths                        1.000000           0.931854            0.932865
# total_distributed             0.931854           1.000000            0.998585
# total_administered            0.932865           0.998585            1.000000
# percent_vaccinated           -0.343160          -0.298033           -0.285802
# est_percent_infected_to_date  0.090186           0.019982            0.018093
# est_percent_immune           -0.225482          -0.233115           -0.224211
#
#                               percent_vaccinated  \
# population                             -0.332108
# Latitude                                0.417061
# Longitude                              -0.387152
# cases                                  -0.334255
# deaths                                 -0.343160
# total_distributed                      -0.298033
# total_administered                     -0.285802
# percent_vaccinated                      1.000000
# est_percent_infected_to_date           -0.078853
# est_percent_immune                      0.775644
#
#                               est_percent_infected_to_date  est_percent_immune
# population                                        0.025753           -0.257631
# Latitude                                          0.026220            0.360593
# Longitude                                        -0.038763           -0.343043
# cases                                             0.130018           -0.193422
# deaths                                            0.090186           -0.225482
# total_distributed                                 0.019982           -0.233115
# total_administered                                0.018093           -0.224211
# percent_vaccinated                               -0.078853            0.775644
# est_percent_infected_to_date                      1.000000            0.568037
# est_percent_immune                                0.568037            1.000000
