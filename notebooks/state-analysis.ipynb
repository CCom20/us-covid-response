# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
state_master_df = pd.read_csv("../data/state-master-data.csv")

# %%
state_master_df.head(10)
# Out:
#    Unnamed: 0                 state Abb        date  population   Latitude  \
# 0           0               Alabama  AL  2021-02-16     4903185  32.601011
# 1           1                Alaska  AK  2021-02-16      731545  61.302501
# 2           2               Arizona  AZ  2021-02-16     7278717  34.168219
# 3           3              Arkansas  AR  2021-02-16     3017804  34.751928
# 4           4            California  CA  2021-02-16    39512223  37.271875
# 5           5              Colorado  CO  2021-02-16     5758736  38.997934
# 6           6           Connecticut  CT  2021-02-16     3565287  41.518784
# 7           7              Delaware  DE  2021-02-16      973764  39.145251
# 8           8  District of Columbia  DC  2021-02-16      705749  38.899349
# 9           9               Florida  FL  2021-02-16    21477737  27.975728
#
#     Longitude    cases  deaths  total_distributed  total_administered  \
# 0  -86.680736   482488    9257            1015775              636682
# 1 -158.775020    56504     276             271550              191008
# 2 -111.930907   799944   14981            1396475             1154583
# 3  -92.131378   313525    5287             631675              483438
# 4 -119.270415  3498760   47446            8250650             6210992
# 5 -105.550567   417688    5932            1224575             1000597
# 6  -72.757507   270822    7449             914075              711142
# 7  -75.418921    83369    1291             189050              152387
# 8  -77.014567    39131     982             193900              126500
# 9  -83.833017  1837277   29153            4597575             3598996
#
#    percent_vaccinated  est_percent_infected_to_date  est_percent_immune
# 0               12.99                          9.86               22.87
# 1               26.11                          7.73               33.85
# 2               15.86                         11.01               26.91
# 3               16.02                         10.41               26.46
# 4               15.72                          8.87               24.60
# 5               17.38                          7.26               24.65
# 6               19.95                          7.61               27.60
# 7               15.65                          8.57               24.24
# 8               17.92                          5.55               23.50
# 9               16.76                          8.57               25.35

# %%
state_master_df.drop(columns={"Unnamed: 0"}, inplace=True)

# %%
state_master_df.corr()
# Out:
#                               population  Latitude  Longitude     cases  \
# population                      1.000000 -0.299618   0.005917  0.988342
# Latitude                       -0.299618  1.000000  -0.055195 -0.313490
# Longitude                       0.005917 -0.055195   1.000000 -0.018893
# cases                           0.988342 -0.313490  -0.018893  1.000000
# deaths                          0.956464 -0.309725   0.078314  0.957106
# total_distributed               0.995735 -0.280843   0.009116  0.982686
# total_administered              0.997150 -0.290135   0.002523  0.983986
# percent_vaccinated             -0.256879  0.447458  -0.305179 -0.262800
# est_percent_infected_to_date    0.029008  0.028942  -0.044377  0.136292
# est_percent_immune             -0.168933  0.355779  -0.261491 -0.089036
#
#                                 deaths  total_distributed  total_administered  \
# population                    0.956464           0.995735            0.997150
# Latitude                     -0.309725          -0.280843           -0.290135
# Longitude                     0.078314           0.009116            0.002523
# cases                         0.957106           0.982686            0.983986
# deaths                        1.000000           0.951727            0.949181
# total_distributed             0.951727           1.000000            0.997077
# total_administered            0.949181           0.997077            1.000000
# percent_vaccinated           -0.285888          -0.233290           -0.213704
# est_percent_infected_to_date  0.106606           0.020941            0.021048
# est_percent_immune           -0.129026          -0.157687           -0.142961
#
#                               percent_vaccinated  \
# population                             -0.256879
# Latitude                                0.447458
# Longitude                              -0.305179
# cases                                  -0.262800
# deaths                                 -0.285888
# total_distributed                      -0.233290
# total_administered                     -0.213704
# percent_vaccinated                      1.000000
# est_percent_infected_to_date           -0.148606
# est_percent_immune                      0.629443
#
#                               est_percent_infected_to_date  est_percent_immune
# population                                        0.029008           -0.168933
# Latitude                                          0.028942            0.355779
# Longitude                                        -0.044377           -0.261491
# cases                                             0.136292           -0.089036
# deaths                                            0.106606           -0.129026
# total_distributed                                 0.020941           -0.157687
# total_administered                                0.021048           -0.142961
# percent_vaccinated                               -0.148606            0.629443
# est_percent_infected_to_date                      1.000000            0.674874
# est_percent_immune                                0.674874            1.000000
