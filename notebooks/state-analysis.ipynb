# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
state_master_df = pd.read_csv("../data/state-master-data.csv")

# %%
state_master_df.head(10)
# Out:
#    Unnamed: 0                 state Abb        date  population   Latitude  \
# 0           0               Alabama  AL  2021-01-28     4903185  32.601011
# 1           1                Alaska  AK  2021-01-28      731545  61.302501
# 2           2               Arizona  AZ  2021-01-28     7278717  34.168219
# 3           3              Arkansas  AR  2021-01-28     3017804  34.751928
# 4           4            California  CA  2021-01-28    39512223  37.271875
# 5           5              Colorado  CO  2021-01-28     5758736  38.997934
# 6           6           Connecticut  CT  2021-01-28     3565287  41.518784
# 7           7              Delaware  DE  2021-01-28      973764  39.145251
# 8           8  District of Columbia  DC  2021-01-28      705749  38.899349
# 9           9               Florida  FL  2021-01-28    21477737  27.975728
#
#     Longitude    cases  deaths  total_distributed  total_administered  \
# 0  -86.680736   452734    7340             493125              165919
# 1 -158.775020    53524     253             154325               71907
# 2 -111.930907   745976   12861             797550              303899
# 3  -92.131378   290856    4784             361550              173312
# 4 -119.270415  3272349   39527            4379500             1633875
# 5 -105.550567   394668    5670             657250              353194
# 6  -72.757507   248765    7020             435075              264707
# 7  -75.418921    76495    1075             106600               49369
# 8  -77.014567    36132     902              75175               55108
# 9  -83.833017  1687586   26034            2546050             1239975
#
#    percent_vaccinated  est_percent_infected_to_date  est_percent_immune
# 0                3.38                          9.25               12.64
# 1                9.83                          7.32               17.15
# 2                4.18                         10.27               14.45
# 3                5.74                          9.65               15.41
# 4                4.14                          8.29               12.43
# 5                6.13                          6.86               13.00
# 6                7.42                          6.99               14.43
# 7                5.07                          7.86               12.94
# 8                7.81                          5.13               12.94
# 9                5.77                          7.87               13.65

# %%
state_master_df.drop(columns={"Unnamed: 0"}, inplace=True)

# %%
state_master_df.corr()
# Out:
#                               population  Latitude  Longitude     cases  \
# population                      1.000000 -0.281456   0.040734  0.987217
# Latitude                       -0.281456  1.000000  -0.050076 -0.293092
# Longitude                       0.040734 -0.050076   1.000000  0.006952
# cases                           0.987217 -0.293092   0.006952  1.000000
# deaths                          0.918365 -0.247886   0.145312  0.903786
# total_distributed               0.994599 -0.275706   0.036562  0.979528
# total_administered              0.980889 -0.292514   0.066543  0.961603
# percent_vaccinated             -0.313495  0.341142  -0.150084 -0.315570
# est_percent_infected_to_date   -0.005354  0.059889  -0.082312  0.104957
# est_percent_immune             -0.166744  0.229612  -0.150756 -0.068788
#
#                                 deaths  total_distributed  total_administered  \
# population                    0.918365           0.994599            0.980889
# Latitude                     -0.247886          -0.275706           -0.292514
# Longitude                     0.145312           0.036562            0.066543
# cases                         0.903786           0.979528            0.961603
# deaths                        1.000000           0.911489            0.935537
# total_distributed             0.911489           1.000000            0.977386
# total_administered            0.935537           0.977386            1.000000
# percent_vaccinated           -0.271162          -0.288279           -0.216335
# est_percent_infected_to_date  0.044038          -0.016347           -0.016257
# est_percent_immune           -0.100308          -0.163572           -0.126334
#
#                               percent_vaccinated  \
# population                             -0.313495
# Latitude                                0.341142
# Longitude                              -0.150084
# cases                                  -0.315570
# deaths                                 -0.271162
# total_distributed                      -0.288279
# total_administered                     -0.216335
# percent_vaccinated                      1.000000
# est_percent_infected_to_date           -0.078385
# est_percent_immune                      0.445500
#
#                               est_percent_infected_to_date  est_percent_immune
# population                                       -0.005354           -0.166744
# Latitude                                          0.059889            0.229612
# Longitude                                        -0.082312           -0.150756
# cases                                             0.104957           -0.068788
# deaths                                            0.044038           -0.100308
# total_distributed                                -0.016347           -0.163572
# total_administered                               -0.016257           -0.126334
# percent_vaccinated                               -0.078385            0.445500
# est_percent_infected_to_date                      1.000000            0.857604
# est_percent_immune                                0.857604            1.000000
