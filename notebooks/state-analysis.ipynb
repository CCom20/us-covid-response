# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
state_master_df = pd.read_csv("../data/state-master-data.csv")

# %%
state_master_df.head(10)
# Out:
#    Unnamed: 0                 state Abb        date  population   Latitude  \
# 0           0               Alabama  AL  2021-01-31     4903185  32.601011
# 1           1                Alaska  AK  2021-01-31      731545  61.302501
# 2           2               Arizona  AZ  2021-01-31     7278717  34.168219
# 3           3              Arkansas  AR  2021-01-31     3017804  34.751928
# 4           4            California  CA  2021-01-31    39512223  37.271875
# 5           5              Colorado  CO  2021-01-31     5758736  38.997934
# 6           6           Connecticut  CT  2021-01-31     3565287  41.518784
# 7           7              Delaware  DE  2021-01-31      973764  39.145251
# 8           8  District of Columbia  DC  2021-01-31      705749  38.899349
# 9           9               Florida  FL  2021-01-31    21477737  27.975728
#
#     Longitude    cases  deaths  total_distributed  total_administered  \
# 0  -86.680736   459639    7688             659400              358280
# ...

# %%
state_master_df.drop(columns={"Unnamed: 0"}, inplace=True)

# %%
state_master_df.corr()
# Out:
#                               population  Latitude  Longitude     cases  \
# population                      1.000000 -0.281456   0.040734  0.987559
# Latitude                       -0.281456  1.000000  -0.050076 -0.294293
# Longitude                       0.040734 -0.050076   1.000000  0.008204
# cases                           0.987559 -0.294293   0.008204  1.000000
# deaths                          0.921895 -0.249747   0.142194  0.909146
# total_distributed               0.995373 -0.271167   0.045752  0.980085
# total_administered              0.996236 -0.272556   0.052457  0.977792
# percent_vaccinated             -0.298157  0.407342  -0.185876 -0.314191
# est_percent_infected_to_date    0.001261  0.050842  -0.075199  0.110547
# est_percent_immune             -0.194260  0.310025  -0.185388 -0.112020
#
#                                 deaths  total_distributed  total_administered  \
# population                    0.921895           0.995373            0.996236
# ...
