# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
state_master_df = pd.read_csv("../data/state-master-data.csv")

# %%
state_master_df.head(10)
# Out:
#    Unnamed: 0                 state Abb        date  population   Latitude  \
# 0           0               Alabama  AL  2021-02-12     4903185  32.601011
# 1           1                Alaska  AK  2021-02-12      731545  61.302501
# 2           2               Arizona  AZ  2021-02-12     7278717  34.168219
# 3           3              Arkansas  AR  2021-02-12     3017804  34.751928
# 4           4            California  CA  2021-02-12    39512223  37.271875
# 5           5              Colorado  CO  2021-02-12     5758736  38.997934
# 6           6           Connecticut  CT  2021-02-12     3565287  41.518784
# 7           7              Delaware  DE  2021-02-12      973764  39.145251
# 8           8  District of Columbia  DC  2021-02-12      705749  38.899349
# 9           9               Florida  FL  2021-02-12    21477737  27.975728
#
#     Longitude    cases  deaths  total_distributed  total_administered  \
# 0  -86.680736   478667    9180             963600              601159
# 1 -158.775020    56008     271             271550              175138
# 2 -111.930907   794224   14843            1393475             1041021
# 3  -92.131378   311608    5212             630700              457386
# 4 -119.270415  3469853   46435            8051475             5562553
# 5 -105.550567   414171    5893            1210475              885581
# 6  -72.757507   267337    7381             847200              654766
# 7  -75.418921    82263    1269             188075              142103
# 8  -77.014567    38670     976             193900              116261
# 9  -83.833017  1814414   28564            4441375             3351430
#
#    percent_vaccinated  est_percent_infected_to_date  est_percent_immune
# 0               12.26                          9.78               22.06
# 1               23.94                          7.66               31.61
# 2               14.30                         10.93               25.27
# 3               15.16                         10.34               25.53
# 4               14.08                          8.79               22.89
# 5               15.38                          7.20               22.59
# 6               18.37                          7.51               25.92
# 7               14.59                          8.46               23.07
# 8               16.47                          5.49               21.98
# 9               15.60                          8.46               24.08

# %%
state_master_df.drop(columns={"Unnamed: 0"}, inplace=True)

# %%
state_master_df.corr()
# Out:
#                               population  Latitude  Longitude     cases  \
# population                      1.000000 -0.281456   0.040734  0.988342
# Latitude                       -0.281456  1.000000  -0.050076 -0.297667
# Longitude                       0.040734 -0.050076   1.000000  0.011469
# cases                           0.988342 -0.297667   0.011469  1.000000
# deaths                          0.935705 -0.259009   0.133191  0.928162
# total_distributed               0.996816 -0.266371   0.041867  0.983861
# total_administered              0.997241 -0.277588   0.040459  0.983646
# percent_vaccinated             -0.255264  0.395693  -0.310530 -0.259378
# est_percent_infected_to_date    0.019916  0.030276  -0.053016  0.126044
# est_percent_immune             -0.162510  0.298903  -0.256698 -0.083469
#
#                                 deaths  total_distributed  total_administered  \
# population                    0.935705           0.996816            0.997241
# Latitude                     -0.259009          -0.266371           -0.277588
# Longitude                     0.133191           0.041867            0.040459
# cases                         0.928162           0.983861            0.983646
# deaths                        1.000000           0.934888            0.931994
# total_distributed             0.934888           1.000000            0.996011
# total_administered            0.931994           0.996011            1.000000
# percent_vaccinated           -0.268203          -0.237882           -0.212372
# est_percent_infected_to_date  0.080854           0.012560            0.013136
# est_percent_immune           -0.123989          -0.156039           -0.137806
#
#                               percent_vaccinated  \
# population                             -0.255264
# Latitude                                0.395693
# Longitude                              -0.310530
# cases                                  -0.259378
# deaths                                 -0.268203
# total_distributed                      -0.237882
# total_administered                     -0.212372
# percent_vaccinated                      1.000000
# est_percent_infected_to_date           -0.076683
# est_percent_immune                      0.638123
#
#                               est_percent_infected_to_date  est_percent_immune
# population                                        0.019916           -0.162510
# Latitude                                          0.030276            0.298903
# Longitude                                        -0.053016           -0.256698
# cases                                             0.126044           -0.083469
# deaths                                            0.080854           -0.123989
# total_distributed                                 0.012560           -0.156039
# total_administered                                0.013136           -0.137806
# percent_vaccinated                               -0.076683            0.638123
# est_percent_infected_to_date                      1.000000            0.718730
# est_percent_immune                                0.718730            1.000000
